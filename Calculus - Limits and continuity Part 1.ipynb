# %% [markdown]
# ## Limits
# A limit is defined as a number approached by the function as an independent function’s variable approaches a particular value. For instance, for a function f(x) = 4x, you can say that “The limit of f(x) as x approaches 2 is 8”. Symbolically, it is written as;
#
# ![image.png](attachment:image.png)
#
# We also have a special notation to talk about limits. This is how we would write the limit of fff as xxx approaches 333:
# \begin{aligned} \scriptsize\text{"The limit of..."}&\qquad\scriptsize\text{"...the function }f\text{..."} \\ \searrow\qquad&\qquad\swarrow \\ \LARGE\displaystyle\lim_{x\to 3}&\LARGE f(x) \\ \nearrow\qquad \\ \scriptsize\text{"...as }x\text{ approaches }3\text{."} \end{aligned}
#
# The symbol lim means we're taking a limit of something.
#
# In limits, we want to get infinitely close. and A limit must be the same from both sides.
#
# ### Estimating values from graphs:
# There's an important difference between the value a function is approaching—what we call the limit—and the value of the function itself. Graphs are a great tool for understanding this difference.
# Example:
# ![image-2.png](attachment:image-2.png)
#
# lim g(x)limit represents the limit of g as x approaches 1.
#
# x→1
#
# ![image-3.png](attachment:image-3.png)
#
# The limit seems to be somewhere between y=-2y=−2y, equals, minus, 2 and y=-1y=−1y, equals, minus, 1, but slightly closer to y=-1y=−1y, equals, minus, 1.
#
# The graph of function g has a dashed horizontal line intersecting at x = 1, between the grid lines for y = negative 1 and y = negative 2, slightly closer to y = negative 1
#
# A reasonable estimate for \displaystyle\lim_{x\to 1}g(x) is -1.4−1.4minus, 1, point, 4.
#
# Sometimes the limit value does not equal the function value.
# It's possible for the function value to be different from the limit value. And just because a function is undefined for some xxx-value doesn't mean there's no limit.
# When the function is defined for some xxx-value, that doesn't mean that the limit necessarily exists.
#
# In the example below, the limits x-->2 are different for 2- values and 2+ values, These are one sided limits and since they are not equal, the lim x-->2 does not exist.
# ![image-4.png](attachment:image-4.png)
#
#
# ## Using tables to approximate limit values:
# Limits are a tool for reasoning about function behavior, and tables are a tool for reasoning about limits. One nice thing about tables is that we can get more precise estimates of limits than we'd get by eyeballing graphs.
# When using a table to approximate limits, it's important to create it in a way that simulates the feeling of getting "infinitely close" to some desired xxx-value.
#
# Example:
# Three students were given a function f and asked to estimate $\displaystyle \lim_{x\to 2}f(x) $
# Each student created a table (shown below).
# ![image-5.png](attachment:image-5.png)
# Each table is accurate, but which one is the best for approximating the limit?
# Approximating a limit is all about asking, "As we get closer and closer to our desired x-value (infinitely closer, ideally) from both directions, what's happening to our y-values? Do they appear to be approaching a finite number?"
# Table B does a nice job getting closer and closer to x=2, equals, 2 from both sides.
# Table A does not make it clear which x-value we are approaching, because the x-values increment in constant steps instead of smaller and smaller steps as they near the desired value.
# Table C only approaches x=2, from one side.
# Table B is best for approximating the limit.

# %% [markdown]
# ## Definition of limits:
# Let us consider a real-valued function “f” and the real number “c”, the limit is normally defined as
#
# ![image.png](attachment:image.png)
#
# It is read as “the limit of f of x, as x approaches c equals L”. The “lim” shows limit, and fact that function f(x) approaches the limit L as x approaches c is described by the right arrow.
#
# ## Properties of Limits:
# Assuming ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)
# exist and c is a constant. Then,
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## Limits by direct substitution:
#
# To estimate the value for a limit, we can try to substitute the value directly into the equation to determine the limit, if we can cannot  be determined , the limit does not exists.
# for example:
# ![image.png](attachment:image.png)
# Can be solved as follows:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Limits using algebric manipulation:
#
# To find a limit of any function over a value that cannot be determined by direct subtitution, we can use algebraic manupilation techniques such as
# 1. Factoring
# 2. Rationalizing
# 3. Using Pythagorean identity
# 4. Using double angle identity
#
#
# For example:
# For the following:
# ![image.png](attachment:image.png)
#
# By substituion the value would be 0/0 which is undefined.
# Using the property of squares:
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Strategy in finding limits:
# A simple flow chart to follow while calculating limits:
# ![image.png](attachment:image.png)

# %% [markdown]
# Points to be Noted:
# 1. Direct substitution is the go-to method. Use other methods only when this fails, otherwise you're probably doing more work than you need to be. For example, it would be extra work to factor an expression into a simpler form if direct substitution would have worked without the factoring.
#
# 2. There's a big difference between getting $ b/0 $ and $0/0 $ (where $b \neq 0$). When you get $b/0$ that indicates that the limit doesn't exist and is probably unbounded (an asymptote). In contrast, when you get 0/00/00, slash, 0, that indicates that you don't have enough information to determine whether or not the limit exists, which is why it's called the indeterminate form. If you wind up here, you've got more work to do, which is where the bottom half of the flow chart comes into play.

# %% [markdown]
# ## Squeeze Theorem:
# The Sandwich Theorem or squeeze theorem is used for calculating the limits of given trigonometric functions. This theorem is also known as the pinching theorem. We generally use the Sandwich theorem in calculus, including mathematical analysis. This theorem is probably used to establish the limit of a function by comparing two other functions whose limits are known or surely figured.
#
# Let f, g and h be real functions such that f(x) ≤ g(x) ≤ h(x) for all x in the common domain of definition. For some real number a, if
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
